# %% [markdown]
# # Train CSV Downloader & Merger
#
# Download daily Realtime Trains CSVs and merge into one file.
#
# **Setup:**
# 1. Create a `.env` file in the project root with your credentials:
#    ```
#    REALTIME_TRAINS_USERNAME=your_username
#    REALTIME_TRAINS_PASSWORD=your_password
#    ```
# 2. Add `.env` to `.gitignore`
# 3. Run the cells below

# %%
import sys
import os
from pathlib import Path
from datetime import date, timedelta
from dotenv import load_dotenv

# Load credentials from .env
load_dotenv(override=False)
username = os.getenv("REALTIME_TRAINS_USERNAME")
password = os.getenv("REALTIME_TRAINS_PASSWORD")

# Add src/modules to path to import data_collection
sys.path.insert(0, str(Path("src/modules").resolve()))
from modules.data_collection import collect_csvs_with_browser

print("✓ Setup complete")
# Out:
# ✓ Setup complete

# %%
import subprocess
import sys

# Ensure required packages are installed
packages = ["python-dotenv", "requests", "playwright", "pandas"]
for pkg in packages:
    try:
        __import__(pkg.replace("-", "_"))
        print(f"✓ {pkg} already installed")
    except ImportError:
        print(f"Installing {pkg}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])
        print(f"✓ {pkg} installed")

# Install playwright browsers (required for Playwright to work)
print("\nInstalling Playwright browsers...")
subprocess.check_call([sys.executable, "-m", "playwright", "install"])
print("✓ Playwright browsers installed")

print("\n✓ All packages ready")
# Out:
# Installing python-dotenv...
# ✓ python-dotenv installed
# ✓ requests already installed
# ✓ playwright already installed
# ✓ python-dotenv installed
# ✓ requests already installed
# ✓ playwright already installed
# ✓ pandas already installed
# ✓ nest-asyncio already installed
#
# Installing Playwright browsers...
# ✓ pandas already installed
# ✓ nest-asyncio already installed
#
# Installing Playwright browsers...
# ✓ Playwright browsers installed
#
# ✓ All packages ready
# ✓ Playwright browsers installed
#
# ✓ All packages ready

# %% [markdown]
# ## Configuration
#
# Edit these values to change the date range and save location:

# %%
start_date = date.today() - timedelta(days=366)  # one year ago
end_date = date.today() - timedelta(days=1)  # yesterday
url_template = "https://www.realtimetrains.co.uk/search/detailed/gb-nr:RDG/{yyyy}-{mm}-{dd}/0000-2359?stp=WVC&show=all&order=wtt"
output_file = "../resources/merged_realtime_trains.csv"

print(f"Date range: {start_date} to {end_date}")
print(f"Output: {output_file}")
# Out:
# Date range: 2024-12-03 to 2025-12-03
# Output: ../resources/merged_realtime_trains.csv

# %% [markdown]
# ## Download & Merge
#
# **Before running:** Customize the Playwright selectors in `data_collection.py` for login and download button (see `[CUSTOMIZE]` comments)

# %%
# Debug: Test single day download to see what error occurs
from datetime import date
from modules.data_collection import download_csv_with_browser

test_date = date(2024, 11, 8)
try:
    result = download_csv_with_browser(
        url_template, 
        test_date, 
        "../resources",  # dest_dir
        username=username, 
        password=password
    )
    print(f"✓ Download successful: {result}")
except Exception as e:
    print(f"✗ Error: {type(e).__name__}: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-11' coro=<Connection.run() done, defined at c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#     )
#     ^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 1794, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ✗ Error: NotImplementedError:
# Traceback (most recent call last):
#   File "C:\Users\fcpen\AppData\Local\Temp\ipykernel_31232\4012682927.py", line 7, in <module>
#     result = download_csv_with_browser(
#         url_template,
#     ...<3 lines>...
#         password=password
#     )
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\src\modules\data_collection.py", line 105, in download_csv_with_browser
#     return asyncio.run(_download_csv_with_browser_async(url_template, d, dest_dir, username, password))
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\nest_asyncio.py", line 98, in run_until_complete
#     return f.result()
#            ~~~~~~~~^^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py", line 199, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\src\modules\data_collection.py", line 40, in _download_csv_with_browser_async
#     async with async_playwright() as p:
#                ~~~~~~~~~~~~~~~~^^
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\async_api\_context_manager.py", line 46, in __aenter__
#     playwright = AsyncPlaywright(next(iter(done)).result())
#                                  ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py", line 199, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\venv\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#     )
#     ^
#   File "C:\Users\fcpen\AppData\Local\Programs\Python\Python313\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-06-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-03: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-04: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-05: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-06: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-07: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-08: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-09: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-10: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-11: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-12: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-13: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-14: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-07-31: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-03: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-04: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-05: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-06: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-07: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-08: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-09: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-10: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-11: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-12: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-13: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-14: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-08-31: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-03: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-04: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-05: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-06: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-07: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-08: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-09: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-10: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-11: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-12: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-13: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-14: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-09-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-03: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-04: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-05: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-06: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-07: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-08: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-09: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-10: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-11: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-12: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-13: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-14: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-10-31: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-03: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-04: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-05: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-06: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-07: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-08: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-09: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-10: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-11: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-12: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-13: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-14: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-15: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-16: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-17: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-18: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-19: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-20: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-21: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-22: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-23: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-24: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-25: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-26: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-27: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-28: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-29: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-11-30: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-12-01: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-12-02: Playwright is not installed. Run: pip install playwright && playwright install
# Skipping 2025-12-03: Playwright is not installed. Run: pip install playwright && playwright install
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 collect_csvs_with_browser(start_date, end_date, url_template, output_file,username=username, password=password)
#
# File c:\Users\fcpen\Documents\GitHub\Train_delays_and_services\src\modules\data_collection.py:305, in collect_csvs_with_browser(start_date, end_date, url_template, output_file, dest_dir, username, password)
#     302 		print(f"Skipping {d.isoformat()}: {e}")
#     304 if not downloaded_files:
# --> 305 	raise RuntimeError("No files were downloaded; cannot create merged CSV")
#     307 # concatenate, preserving header from first file only
#     308 first = True
#
# RuntimeError: No files were downloaded; cannot create merged CSV

# %% [markdown]
# ## View Results

# %%
import pandas as pd

df = pd.read_csv(output_file)
print(f"Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
df.head()
